# %% [markdown]
# # Clase 03: Tipos de Datos Abstractos, interfaz y pilas
#
# En esta clase pasamos de **usar** estructuras de datos a **diseñar** estructuras de datos.
#
# Pregunta guía:
#
# > ¿Qué diferencia hay entre usar una estructura de datos y diseñar una estructura de datos?
#
# Idea central:
#
# > Un Tipo de Dato Abstracto describe qué operaciones existen y qué comportamiento se espera, pero no fija una implementación.

# %% [markdown]
# ## Objetivos
#
# Al terminar este notebook podrás:
#
# - Explicar qué es un Tipo de Dato Abstracto.
# - Distinguir entre interfaz e implementación.
# - Conectar TDA con clases y métodos de POO.
# - Reconocer problemas donde una pila aparece como herramienta.
# - Proponer una interfaz básica para una pila.
# - Escribir pruebas mínimas en lenguaje natural.

# %% [markdown]
# ## 1. Preparación
#
# Ejecuta esta celda para poder importar el código auxiliar de la clase.

# %%
from pathlib import Path
import sys

ruta_actual = Path.cwd()
rutas_posibles = [ruta_actual / "src", ruta_actual.parent / "src"]

for ruta in rutas_posibles:
    if ruta.exists():
        sys.path.insert(0, str(ruta))
        break

from herramientas_pila import (
    visitar_pagina,
    regresar,
    pagina_actual,
    registrar_accion,
    deshacer_accion,
    parentesis_balanceados_guiada,
)

print("Código auxiliar importado correctamente.")
# Out:
# Código auxiliar importado correctamente.

# %% [markdown]
# ## 2. Usar contra diseñar
#
# Hasta ahora hemos usado `list`, `set`, `dict` y `Counter`. Sabemos llamar operaciones, comparar costos y elegir una representación.
#
# Diseñar una estructura agrega otra pregunta:
#
# > ¿Qué operaciones debe ofrecer y qué comportamiento debe prometer?

# %% [markdown]
# ### Ejercicio 1: identificar interfaz
#
# Supón que vemos un objeto usado así:
#
# ```python
# estructura.agregar(x)
# estructura.quitar()
# estructura.esta_vacia()
# ```
#
# Responde en una celda Markdown o en tu cuaderno:
#
# 1. ¿Cuál es la interfaz?
# 2. ¿Qué comportamiento esperamos de cada operación?
# 3. ¿Qué no sabemos sobre la implementación?
# 4. ¿Por qué puede ser útil no saberlo?

# %%
uso = """
estructura.agregar(x)
estructura.quitar()
estructura.esta_vacia()
"""

print(uso)
# Out:
# estructura.agregar(x)
# estructura.quitar()
# estructura.esta_vacia()

# %% [markdown]
# ### Tu respuesta
#
# - Interfaz: Los métodos que usa el usuario para interactuar con el código.
# - Comportamiento esperado: Que $agregar$ ponga algo en una pila, que $quitar$ elimine el primer elemento que encuentre y que $esta \_ vacia$ cheque si hay elementos o no, regresando un $true$ o $false$.
# - Detalles de implementación que no conocemos: Como funciona por dentro la estructura.
# - Ventaja de ocultar esos detalles: Te preocupas menos por el como funciona y mas en como implementarlo.

# %% [markdown]
# ## 3. Tipo de Dato Abstracto
#
# Un **Tipo de Dato Abstracto** es un contrato.
#
# Ese contrato describe:
#
# - qué operaciones existen;
# - qué comportamiento se espera;
# - qué casos especiales deben considerarse;
# - qué detalles internos no forman parte de la interfaz.

# %%
tda_pila = {
    "nombre": "Pila",
    "regla": "El último elemento en entrar es el primero en salir",
    "operaciones": ["push", "pop", "peek", "esta_vacia", "tamano"],
    "implementacion_obligatoria": None,
}

for llave, valor in tda_pila.items():
    print(f"{llave}: {valor}")
# Out:
# nombre: Pila
# regla: El último elemento en entrar es el primero en salir
# operaciones: ['push', 'pop', 'peek', 'esta_vacia', 'tamano']
# implementacion_obligatoria: None

# %% [markdown]
# ## 4. Pila: regla LIFO
#
# Una pila sigue la regla **LIFO**:
#
# > Last In, First Out.
#
# En español:
#
# > El último elemento en entrar es el primero en salir.

# %%
pila_simulada = []

pila_simulada.append(10)
pila_simulada.append(20)
pila_simulada.append(30)

print("Estado antes de sacar:", pila_simulada)

ultimo = pila_simulada.pop()

print("Elemento que salió:", ultimo)
print("Estado después de sacar:", pila_simulada)

assert ultimo == 30
# Out:
# Estado antes de sacar: [10, 20, 30]
# Elemento que salió: 30
# Estado después de sacar: [10, 20]

# %% [markdown]
# ### Pregunta clave
#
# ¿Dónde dice que una pila debe usar una lista de Python?
#
# Respuesta esperada:
#
# > En ninguna parte. La lista es una posible implementación, no la definición del TDA.

# %% [markdown]
# ## 5. Historial de navegación
#
# Una pila aparece cuando necesitamos regresar al estado anterior más reciente.
#
# En un historial, la página actual está al final: es lo último que visitamos.

# %%
historial = []

visitar_pagina(historial, "inicio")
visitar_pagina(historial, "temario")
visitar_pagina(historial, "practica-03")

print("Historial:", historial)
print("Página actual:", pagina_actual(historial))

pagina = regresar(historial)
print("Después de regresar:", pagina)
print("Historial:", historial)

assert pagina == "temario"
# Out:
# Historial: ['inicio', 'temario', 'practica-03']
# Página actual: practica-03
# Después de regresar: temario
# Historial: ['inicio', 'temario']

# %%
# Tu turno:
# 1. Crea un historial nuevo.
# 2. Visita al menos tres páginas.
# 3. Usa regresar una vez.
# 4. Explica por qué aparece comportamiento LIFO.

mi_historial = []

# Completa aquí sin borrar las líneas anteriores.

mi_historial 

visitar_pagina(mi_historial, "inicio")
visitar_pagina(mi_historial, "YouTube")
visitar_pagina(mi_historial, "Mundial")

print("Historial:", mi_historial)
print("Página actual:", pagina_actual(mi_historial))

mi_pagina = regresar(mi_historial)
print("Después de regresar:", mi_pagina)
print("Historial:", mi_historial)

assert mi_pagina == "YouTube"
# Out:
# Historial: ['inicio', 'YouTube', 'Mundial']
# Página actual: Mundial
# Después de regresar: YouTube
# Historial: ['inicio', 'YouTube']

# %% [markdown]
# ### Pregunta: ¿Por qué tiene comportamiento tipo LIFO?
# Porque al usar la funcion $visitar \_ pagina$ se van añadiendo cosas al historial en el orden en que se escribieron en el codigo, y al usar $regresar$ la ultima entrada del historial es la primera en salir. Literal la definicion de $Last \ in, First \ out$.

# %% [markdown]
# ### Preguntas
#
# 1. ¿Qué elemento queda al tope del historial?
# 2. ¿Qué página sale cuando usamos `regresar`?
# 3. ¿Qué cambiaría si quisiéramos ir hacia adelante otra vez?
#
# #### Respuestas
# 1. El último en entrar.
# 2. La que estaba debajo de la del tope.
# 3. Tendriamos que agregar una nueva página y por tanto un nuevo tope.

# %% [markdown]
# ## 6. Deshacer acciones
#
# Otra pila natural es la lista de acciones realizadas por un editor.
#
# La última acción suele ser la primera que queremos deshacer.

# %%
acciones = []

registrar_accion(acciones, "escribir A")
registrar_accion(acciones, "escribir B")
registrar_accion(acciones, "borrar B")

print("Acciones realizadas:", acciones)

deshecha = deshacer_accion(acciones)

print("Acción deshecha:", deshecha)
print("Acciones pendientes:", acciones)

assert deshecha == "borrar B"
# Out:
# Acciones realizadas: ['escribir A', 'escribir B', 'borrar B']
# Acción deshecha: borrar B
# Acciones pendientes: ['escribir A', 'escribir B']

# %%
# Tu turno:
# Simula cuatro acciones de un editor y deshaz las dos últimas.

mis_acciones = []

# Completa aquí.

mis_acciones

registrar_accion(mis_acciones, "escribir Pie de pagina")
registrar_accion(mis_acciones, "insertar un espacio")
registrar_accion(mis_acciones, "insertar una imagen")
registrar_accion(mis_acciones, "cortar imagen")

print("Acciones realizadas:", mis_acciones)

deshecha = deshacer_accion(mis_acciones)

print("Acción deshecha:", deshecha)
print("Acciones pendientes:", mis_acciones)

assert deshecha == "cortar imagen"
# Out:
# Acciones realizadas: ['escribir Pie de pagina', 'insertar un espacio', 'insertar una imagen', 'cortar imagen']
# Acción deshecha: cortar imagen
# Acciones pendientes: ['escribir Pie de pagina', 'insertar un espacio', 'insertar una imagen']

# %% [markdown]
# ### Preguntas
#
# 1. ¿Qué se guarda en la pila?
# 2. ¿Por qué el último evento es el primero que se deshace?
# 3. ¿Guardarías texto completo, acciones o ambas cosas? ¿Por qué?
#
# #### Respuestas
# 1. Las acciones que realizó el editor.
# 2. Porque lo que quiere el editor es eliminar la última acción que realizó.
# 3. Ambas cosas, porque si eliminas una palabra que querías mantener, necesitas saber que palabra fue, no solo que escribió una palabra.

# %% [markdown]
# ## 7. Paréntesis balanceados
#
# La pila sirve para recordar símbolos abiertos que aún no han cerrado.
#
# Ejemplos para analizar:
#
# - `(a+b)`
# - `((a+b)`
# - `(a+b))`
# - `[a+(b*c)]`

# %%
def parentesis_balanceados(expresion):
    """Función incompleta para completar en clase."""
    pila = []
    pares = {")": "(", "]": "[", "}": "{"}

    for simbolo in expresion:
        if simbolo in "([{" :
            pila.append(simbolo)
        elif simbolo in pares:
            # TODO:
            # 1. Revisar si la pila está vacía.
            if len(pila) == 0:
                pila.append(simbolo)
            else: 
            # 2. Comparar el cierre con el tope.
                tope = pila.pop()
                # 3. Sacar el tope si coincide.
                if tope != pares[simbolo]:
                    pila.append(simbolo)
                

    # TODO:
    # La expresión está balanceada solo si la pila termina vacía.
    return len(pila) == 0

# %%
casos = [")a+b)","(a+b)", "((a+b)", "(a+b))", "[a+(b*c)]", "{(a+b)*c}+d"]

for caso in casos:
    print(caso, "->", parentesis_balanceados(caso))

print("Resultado pendiente: la función todavía no está completa.")
# Out:
# )a+b) -> False
# (a+b) -> True
# ((a+b) -> False
# (a+b)) -> False
# [a+(b*c)] -> True
# {(a+b)*c}+d -> True
# Resultado pendiente: la función todavía no está completa.

# %%
traza = parentesis_balanceados_guiada("[a+(b*c)]")

for evento in traza:
    print(evento)
# Out:
# {'posicion': 0, 'simbolo': '[', 'accion': 'apilar apertura', 'pila': ['[']}
# {'posicion': 3, 'simbolo': '(', 'accion': 'apilar apertura', 'pila': ['[', '(']}
# {'posicion': 7, 'simbolo': ')', 'accion': 'Desapilar (cierre correspondiente)', 'pila': ['[']}
# {'posicion': 8, 'simbolo': ']', 'accion': 'Desapilar (cierre correspondiente)', 'pila': []}

# %% [markdown]
# ### Preguntas
#
# 1. ¿Qué símbolos se apilan?
# 2. ¿Qué debe ocurrir cuando aparece un símbolo de cierre?
# 3. ¿Qué significa que la pila termine vacía?
# 4. ¿Qué caso de prueba detecta un cierre extra?
#
# #### Respuestas
# 1. Los de apertura y los de cierre.
# 2. Lo debe comprarar con el último elemento de la pila y si son distintos entonces guarda el de cierre en la pila.
# 3. Que a cada simbolo de apertura o cierre, esta su par correspondiente en el otro lado.
# 4. (a+b))

# %% [markdown]
# ## 8. Pila de llamadas
#
# Cuando una función llama a otra, la primera queda pendiente hasta que termine la segunda.
#
# Observemos el orden de entrada y salida.

# %%
eventos = []


def f():
    eventos.append("entra f")
    g()
    eventos.append("sale f")


def g():
    eventos.append("entra g")
    h()
    eventos.append("sale g")


def h():
    eventos.append("entra h")
    eventos.append("hola")
    eventos.append("sale h")


f()

for evento in eventos:
    print(evento)
# Out:
# entra f
# entra g
# entra h
# hola
# sale h
# sale g
# sale f

# %% [markdown]
# ### Preguntas
#
# 1. ¿Cuál función fue llamada primero?
# 2. ¿Cuál función termina primero?
# 3. ¿Por qué esto se parece a una pila?
# 4. ¿Qué relación ves con recursión?
#
# #### Respuestas
# 1. f()
# 2. h()
# 3. Porque el ultimo en entrar es h y tambien es el primero en salir.
# 4. Que se va iterando a traves del llamado de funciones, y que la más externa depende de la más interna.

# %% [markdown]
# ## 9. Diseñar la interfaz de `Pila`
#
# Antes de implementar, necesitamos acordar qué promete la estructura.
#
# Borrador esperado:
#
# ```python
# class Pila:
#     def push(self, elemento):
#         pass
#
#     def pop(self):
#         pass
#
#     def peek(self):
#         pass
#
#     def esta_vacia(self):
#         pass
#
#     def tamano(self):
#         pass
# ```
#
# Hoy no implementaremos esta clase completa. Solo vamos a discutir su interfaz.

# %%
# Completa o ajusta esta propuesta con tus decisiones.

interfaz_propuesta = {
    "push(elemento)": "agrega un elemento al tope",
    "pop()": "elimina y regresa el elemento del tope",
    "peek()": "regresa el elemento del tope sin eliminarlo",
    "esta_vacia()": "regresa True si no hay elementos",
    "tamano()": "regresa la cantidad de elementos",
}

for metodo, descripcion in interfaz_propuesta.items():
    print(f"{metodo}: {descripcion}")
# Out:
# push(elemento): agrega un elemento al tope
# pop(): elimina y regresa el elemento del tope
# peek(): regresa el elemento del tope sin eliminarlo
# esta_vacia(): regresa True si no hay elementos
# tamano(): regresa la cantidad de elementos

# %% [markdown]
# ### Decisiones pendientes
#
# Responde:
#
# 1. ¿Qué debería pasar si hacemos `pop()` sobre una pila vacía?
#     * Nada, debe de marcar error o una leyenda indicando que la pila ya esta vacía.
# 2. ¿Qué debería pasar si hacemos `peek()` sobre una pila vacía?
#     * Marcar una leyenda que inidque que no hay tope porque la pila esta vacía.
# 3. ¿`peek()` debería modificar la pila?
#     * No.
# 4. ¿Conviene usar `push/pop/peek` o nombres completamente en español?
#     * Creo que por convención y por el argot se debería de quedar como push/pop/peek, además de que son mas concisos para indicar su intención.

# %% [markdown]
# ## 10. Pruebas mínimas en lenguaje natural
#
# Antes de implementar, escribimos ejemplos de comportamiento esperado.
#
# Una prueba mínima no tiene que ser código todavía. Debe ser clara.

# %%
pruebas_minimas = [
    "Si apilo 1 y luego 2, entonces pop debe regresar 2.",
    "Si apilo 1 y luego 2, entonces peek debe regresar 2 sin eliminarlo.",
    "Una pila recién creada debe estar vacía.",
    "Después de apilar un elemento, esta_vacia debe regresar False.",
    "Si la pila esta vacia, entonces pop regresa None o una excepción.",
]

for prueba in pruebas_minimas:
    print("-", prueba)
# Out:
# - Si apilo 1 y luego 2, entonces pop debe regresar 2.
# - Si apilo 1 y luego 2, entonces peek debe regresar 2 sin eliminarlo.
# - Una pila recién creada debe estar vacía.
# - Después de apilar un elemento, esta_vacia debe regresar False.
# - Si la pila esta vacia, entonces pop regresa None o una excepción.

# %% [markdown]
# ## 11. Actividad GitHub
#
# Cada estudiante debe crear:
#
# ```text
# entregas/clase_03/tu_nombre.md
# ```
#
# El archivo debe contener:
#
# - Definición propia de TDA.
# - Diferencia entre interfaz e implementación.
# - Un problema donde usaría una pila.
# - Propuesta de interfaz para `Pila`.
# - Una prueba mínima en lenguaje natural.
#
# Flujo esperado:
#
# ```text
# Issue → Branch → Commit → Pull Request → Review
# ```

# %% [markdown]
# ## 12. Reto opcional
#
# Sin implementar una clase `Pila`, escribe más casos de prueba en lenguaje natural para estos escenarios:
#
# 1. `peek()` varias veces seguidas.
# 2. `tamano()` después de varios `push` y `pop`.
# 3. `pop()` hasta vaciar la pila.
# 4. Usar la pila para revisar paréntesis con `()`, `[]` y `{}`.
#
# Guarda tus pruebas en tu entrega de GitHub.

# %%
pruebas_minimas = [
    "Si apilo 1 y luego 2, entonces pop debe regresar 2.",
    "Si apilo 1 y luego 2, entonces peek debe regresar 2 sin eliminarlo.",
    "Una pila recién creada debe estar vacía.",
    "Después de apilar un elemento, esta_vacia debe regresar False."
    "Si apilo 1 y luego 2, entonces peek debe regresar 2 sin eliminarlo, si vuelvo a usar peek, entonces debe regresar 2 sin eliminarlo.",
    "Si apilo 1, 2 y 3, y hago un pop, luego un push, luego un pop, luego un push entonces tamano debe regresar 3. (se debe actualizar el tamaño de la pila).",
    "Si la pila esta vacia y hago un pop entonces debe regresar None o marcar una excepeción.",
    "Si apilo 1, 2 y 3 y hago pop 3 veces la pila se debe vaciar. Si se vuelve a hacer pop es el caso anterior.",
    "Si uso la pila para revisar la cadena '{[()]}', cada símbolo de cierre debe coincidir con el tope de la pila, y al finalizar, la pila debe quedar vacía.", 
    "Si reviso la cadena '(]', al procesar el corchete de cierre, el tope de la pila será un paréntesis, por lo que el sistema debe detectar un error por incompatibilidad.",
    "Si reviso la cadena '())', al llegar al último paréntesis de cierre la pila ya estará vacía, lo que debe arrojar un error de cierre sin apertura."
    "Si reviso la cadena '(()', al terminar de leer todo el texto, la pila terminará con un elemento adentro, indicando que la expresión está desbalanceada porque faltó un cierre."
]

for prueba in pruebas_minimas:
    print("-", prueba)
# Out:
# - Si apilo 1 y luego 2, entonces pop debe regresar 2.
# - Si apilo 1 y luego 2, entonces peek debe regresar 2 sin eliminarlo.
# - Una pila recién creada debe estar vacía.
# - Después de apilar un elemento, esta_vacia debe regresar False.Si apilo 1 y luego 2, entonces peek debe regresar 2 sin eliminarlo, si vuelvo a usar peek, entonces debe regresar 2 sin eliminarlo.
# - Si apilo 1, 2 y 3, y hago un pop, luego un push, luego un pop, luego un push entonces tamano debe regresar 3. (se debe actualizar el tamaño de la pila).
# - Si la pila esta vacia y hago un pop entonces debe regresar None o marcar una excepeción.
# - Si apilo 1, 2 y 3 y hago pop 3 veces la pila se debe vaciar. Si se vuelve a hacer pop es el caso anterior.
# - Si uso la pila para revisar la cadena '{[()]}', cada símbolo de cierre debe coincidir con el tope de la pila, y al finalizar, la pila debe quedar vacía.
# - Si reviso la cadena '(]', al procesar el corchete de cierre, el tope de la pila será un paréntesis, por lo que el sistema debe detectar un error por incompatibilidad.
# - Si reviso la cadena '())', al llegar al último paréntesis de cierre la pila ya estará vacía, lo que debe arrojar un error de cierre sin apertura.Si reviso la cadena '(()', al terminar de leer todo el texto, la pila terminará con un elemento adentro, indicando que la expresión está desbalanceada porque faltó un cierre.

# %% [markdown]
# ## Reflexión
#
# Responde:
#
# 1. ¿Qué diferencia ves entre usar una pila y diseñar una pila?
#     * Usar la pila es algo más "sencillo", confiamos en la estructura de la lista de python y con eso basta. Sin embargo, al diseñar una pila necesitamos tomar en cuenta varios casos, lo que queremos que haga y que cumpla el LIFO.
# 2. ¿Qué parte de la interfaz te parece más importante?
#     * Que tenga el comportamiento prometido, pues si es asi los métodos que se pueden llamar son confiables y será estable.
# 3. ¿Qué decisión dejarías abierta para la implementación de la Clase 04?
#     * Como definimos el resultado donde la pila este vacia y hagamos un $pop$, si con un $None$ o una excepcion, y como hacemos uso de $esta \_ vacia$
# 4. ¿Qué aprendiste al revisar el Pull Request de otra persona?
#     * Que hay que tener cuidado en como creamos las carpetas, que es importante que todo lleve nuestro nombre para saber a quién estamos revisando y hacer el procedimiento del commit y el push con cuidado para no mandar mas archivos de los necesarios.

# %% [markdown]
# ## Cierre
#
# La Clase 04 partirá de esta pregunta:
#
# > Ya sabemos qué debe hacer una pila. Ahora, ¿cómo la implementamos?
#
# Tema sugerido: implementar `Pila` usando `list` de Python.
