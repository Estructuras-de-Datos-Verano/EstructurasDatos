# %% [markdown]
# # Clase 13: Árboles AVL
#
# ## Pregunta inicial
#
# Si un BST puede convertirse en una lista, ¿cómo podemos impedirlo?
#
# > [!IMPORTANT]
# > No respondas dentro de este notebook. Tus respuestas van en `notebook.md`, siguiendo el mismo orden.

# %% [markdown]
# ## Objetivos
#
# Al final de la clase deberías poder:
#
# - explicar balance en árboles;
# - calcular factores de balance;
# - reconocer casos `LL`, `RR`, `LR` y `RL`;
# - argumentar por qué una rotación preserva el invariante del BST;
# - implementar inserción AVL;
# - escribir pruebas para rotaciones;
# - preparar una revisión técnica en Markdown.

# %% [markdown]
# ## 1. Motivación
#
# En Clase 12 vimos dos árboles con los mismos valores:
#
# - uno de baja altura;
# - otro degenerado, parecido a una lista.
#
# **Pregunta para `notebook.md`:** ¿por qué un BST básico no garantiza por sí solo búsquedas rápidas?

# %% [markdown]
# ## 2. Degeneración
#
# Insertar valores ordenados en un BST básico puede producir una cadena.
#
# ```text
# 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> 7
# ```
#
# **Pregunta para `notebook.md`:** ¿qué operación se vuelve costosa cuando el árbol se degenera?

# %% [markdown]
# ## 3. Altura y balance
#
# Usaremos la misma convención de la Clase 12:
#
# - árbol vacío: altura 0;
# - árbol con solo raíz: altura 1.
#
# Un árbol está localmente balanceado si las alturas de los hijos de cada nodo no difieren demasiado.
#
# > [!NOTE]
# > AVL exige que la diferencia sea a lo más 1 en valor absoluto.

# %%
def factor_balance(altura_izquierda: int, altura_derecha: int) -> int:
    """Calcula altura_izquierda - altura_derecha."""

    return altura_izquierda - altura_derecha


casos = [(2, 0), (0, 2), (2, 1), (1, 2)]
for izquierda, derecha in casos:
    print(izquierda, derecha, factor_balance(izquierda, derecha))

# %% [markdown]
# **Pregunta para `notebook.md`:** si un nodo tiene factor de balance `2`, ¿hacia qué lado está cargado?

# %% [markdown]
# ## 4. Ingeniería inversa del algoritmo
#
# Antes de escribir una sola línea de AVL, responde en `notebook.md`:
#
# 1. ¿Qué problema intenta resolver AVL?
# 2. ¿Qué información extra debe recordar cada nodo?
# 3. ¿Qué operación se repite después de insertar?
# 4. ¿Qué propiedad debe conservarse aunque rotemos?
# 5. ¿Cómo detectarías con papel y lápiz que hace falta una rotación?
# 6. Escribe pseudocódigo breve de inserción AVL.

# %% [markdown]
# ## 5. Descubrimiento de las rotaciones
#
# Una rotación cambia enlaces locales. Lo crucial es que no cambia el recorrido inorden.
#
# > [!TIP]
# > Si después de rotar el inorden sigue ordenado y contiene los mismos valores, el invariante BST sobrevivió.

# %% [markdown]
# ## 6. Caso LL
#
# **Secuencias:** nivel 1 `30, 20, 10`; nivel 2 `40, 20, 60, 10, 30, 50, 70, 5, 2`; nivel 3 `50, 30, 70, 20, 40, 60, 80, 10, 5, 65, 75, 85`.
#
# ![LL mínimo](gifs/avl_ll_rotacion_derecha.gif)
#
# ![LL local](gifs/avl_ll_nivel_2_local.gif)
#
# ![LL evolución](gifs/avl_ll_nivel_3_evolucion.gif)
#
# La inserción cae en el subárbol izquierdo del hijo izquierdo. En el nodo desbalanceado, `FB = +2`; una rotación derecha hace subir al hijo izquierdo.
#
# | Estado | Raíz local | Altura local | Factor en 30 | Inorden |
# |---|---:|---:|---:|---|
# | Antes | 30 | 3 | +2 | 10, 20, 30 |
# | Después | 20 | 2 | 0 | 10, 20, 30 |
#
# > [!NOTE]
# > En los niveles 2 y 3, identifica los nodos que no cambian de padre: la rotación es local.
#
# **Responde en `notebook.md`:**
#
# 1. ¿Qué observas que cambia en la forma del subárbol?
# 2. ¿Cómo se obtiene el factor `+2` del nodo 30?
# 3. ¿Por qué la corrección es una rotación derecha?
# 4. ¿Por qué el inorden debe ser `10, 20, 30` antes y después?

# %% [markdown]
# ## 7. Caso RR
#
# **Secuencias:** nivel 1 `10, 20, 30`; nivel 2 `40, 20, 60, 10, 30, 50, 70, 75, 80`; nivel 3 `50, 30, 70, 20, 40, 60, 80, 90, 95, 25, 45, 65`.
#
# ![RR mínimo](gifs/avl_rr_rotacion_izquierda.gif)
#
# ![RR local](gifs/avl_rr_nivel_2_local.gif)
#
# ![RR evolución](gifs/avl_rr_nivel_3_evolucion.gif)
#
# La inserción cae en el subárbol derecho del hijo derecho. En el nodo desbalanceado, `FB = -2`; una rotación izquierda hace subir al hijo derecho.
#
# | Estado | Raíz local | Altura local | Factor en 10 | Inorden |
# |---|---:|---:|---:|---|
# | Antes | 10 | 3 | -2 | 10, 20, 30 |
# | Después | 20 | 2 | 0 | 10, 20, 30 |
#
# > [!TIP]
# > Usa LL como espejo: cambia izquierda por derecha y el signo del factor.
#
# **Responde en `notebook.md`:**
#
# 1. ¿Qué parte del árbol permanece estable en el nivel 2?
# 2. ¿Por qué el factor de balance es negativo?
# 3. ¿Por qué la corrección es una rotación izquierda?
# 4. Comprueba el inorden antes y después de rotar.

# %% [markdown]
# ## 8. Caso LR
#
# **Secuencias:** nivel 1 `30, 10, 20`; nivel 2 `40, 20, 60, 10, 30, 50, 70, 5, 8`; nivel 3 `50, 30, 70, 20, 40, 60, 80, 10, 15, 35, 45, 65`.
#
# ![LR mínimo](gifs/avl_lr_rotacion_doble.gif)
#
# ![LR local](gifs/avl_lr_nivel_2_local.gif)
#
# ![LR evolución](gifs/avl_lr_nivel_3_evolucion.gif)
#
# La inserción cae a la derecha del hijo izquierdo. Primero se rota a la izquierda sobre ese hijo; después, a la derecha sobre el nodo desbalanceado.
#
# | Estado | Raíz local | Altura local | Corrección | Inorden |
# |---|---:|---:|---|---|
# | Antes | 30 | 3 | pendiente | 10, 20, 30 |
# | Intermedio | 30 | 3 | izquierda sobre 10 | 10, 20, 30 |
# | Después | 20 | 2 | derecha sobre 30 | 10, 20, 30 |
#
# > [!IMPORTANT]
# > La rotación cambia la forma del árbol, pero no debe cambiar el orden inorden.
#
# **Responde en `notebook.md`:**
#
# 1. ¿Qué nodo ocupa la posición interior que obliga a usar dos pasos?
# 2. ¿Cuál es el factor del nodo 30 cuando se detecta LR?
# 3. ¿Qué corrige la primera rotación y qué corrige la segunda?
# 4. Verifica el inorden en los tres estados de la tabla.

# %% [markdown]
# ## 9. Caso RL
#
# **Secuencias:** nivel 1 `10, 30, 20`; nivel 2 `40, 20, 60, 10, 30, 50, 70, 75, 72`; nivel 3 `50, 30, 70, 20, 40, 60, 80, 90, 85, 25, 45, 65`.
#
# ![RL mínimo](gifs/avl_rl_rotacion_doble.gif)
#
# ![RL local](gifs/avl_rl_nivel_2_local.gif)
#
# ![RL evolución](gifs/avl_rl_nivel_3_evolucion.gif)
#
# La inserción cae a la izquierda del hijo derecho. Primero se rota a la derecha sobre ese hijo; después, a la izquierda sobre el nodo desbalanceado.
#
# | Estado | Raíz local | Altura local | Corrección | Inorden |
# |---|---:|---:|---|---|
# | Antes | 10 | 3 | pendiente | 10, 20, 30 |
# | Intermedio | 10 | 3 | derecha sobre 30 | 10, 20, 30 |
# | Después | 20 | 2 | izquierda sobre 10 | 10, 20, 30 |
#
# > [!WARNING]
# > Aplicar solo la rotación izquierda sobre 10 no coloca correctamente al pivote interior.
#
# **Responde en `notebook.md`:**
#
# 1. ¿En qué sentido RL es el espejo de LR?
# 2. ¿Por qué el factor del nodo 10 es `-2`?
# 3. ¿En qué orden se aplican las dos rotaciones?
# 4. Explica por qué el inorden no cambia.

# %% [markdown]
# ## 10. Comparación entre BST y AVL
#
# Usamos exactamente la secuencia `1, 2, 3, ..., 12` en ambos árboles. Observa altura, profundidad máxima, cantidad de rotaciones e inorden en cada paso.
#
# ![BST contra AVL](gifs/bst_vs_avl.gif)
#
# > [!CAUTION]
# > Tener el mismo inorden no implica tener el mismo costo de búsqueda: la forma y la altura importan.
#
# **Responde en `notebook.md`:** ¿en qué momento se separan claramente las alturas y qué trabajo adicional realiza AVL?

# %% [markdown]
# ## 11. Cuando no hace falta rotar
#
# Secuencia: `20, 10, 30, 5, 15, 25, 35`.
#
# ![AVL sin rotaciones](gifs/avl_sin_rotacion.gif)
#
# > [!NOTE]
# > Si todos los factores están en `[-1, 1]`, el árbol ya cumple el invariante AVL.
#
# **Responde en `notebook.md`:** ¿por qué una rotación sería innecesaria e incluso confusa en este ejemplo?

# %% [markdown]
# ## 12. Varias rotaciones durante una secuencia
#
# Secuencia: `10, 20, 30, 40, 50, 25, 5, 4, 3`.
#
# ![AVL con varias rotaciones](gifs/avl_multiples_rotaciones.gif)
#
# > [!TIP]
# > Cuenta las rotaciones acumuladas y observa que el balance se restaura después de cada inserción que lo necesita.
#
# **Responde en `notebook.md`:** identifica los casos que aparecen y explica por qué AVL se mantiene balanceado continuamente.

# %% [markdown]
# ## 13. Interfaz esperada
#
# Tu entrega debe implementar:
#
# ```python
# class NodoAVL:
#     ...
#
# class ArbolAVL:
#     def insertar(self, valor: int) -> None: ...
#     def contiene(self, valor: int) -> bool: ...
#     def altura(self) -> int: ...
#     def inorden(self) -> list[int]: ...
#     def esta_balanceado(self) -> bool: ...
# ```

# %%
# Esta celda no implementa la solución.
# Úsala como checklist conceptual antes de escribir código en implementacion.py.

pasos_insercion_avl = [
    "insertar como BST",
    "actualizar altura",
    "calcular factor de balance",
    "identificar LL/RR/LR/RL",
    "rotar si hace falta",
    "devolver nueva raíz local",
]

for paso in pasos_insercion_avl:
    print("-", paso)

# %% [markdown]
# ## 14. Complejidad
#
# Un AVL busca mantener altura proporcional a `log n`.
#
# **Pregunta para `notebook.md`:** ¿qué costo adicional pagamos al insertar para conservar baja la altura?

# %% [markdown]
# ## 15. Pruebas
#
# Las pruebas públicas verifican:
#
# - árbol vacío;
# - inserción;
# - recorrido inorden;
# - casos `LL`, `RR`, `LR`, `RL`;
# - altura;
# - balance;
# - duplicados.
#
# > [!WARNING]
# > Pasar las pruebas públicas no prueba todo. Debes escribir al menos tres pruebas propias.

# %% [markdown]
# ## 16. `notebook.md` y `discusion.md`
#
# `notebook.md` es un documento de trabajo: contiene respuestas guiadas.
#
# `discusion.md` es un documento técnico: argumenta decisiones de diseño, complejidad, pruebas y revisión.
#
# **Pregunta para `notebook.md`:** escribe una diferencia concreta entre ambos documentos.

# %% [markdown]
# ## 17. Revisión técnica
#
# A partir de esta clase, además de comentar en GitHub, debes agregar un archivo dentro de la carpeta del compañero:
#
# ```text
# entregas/aristeo/clase_13/revision_max.md
# ```
#
# **Pregunta para `notebook.md`:** ¿qué evidencia debe incluir una buena revisión técnica?

# %% [markdown]
# ## 18. Problemas relacionados
#
# LeetCode:
#
# - 110 Balanced Binary Tree.
# - 98 Validate Binary Search Tree.
# - 701 Insert into a Binary Search Tree.
# - 1382 Balance a Binary Search Tree.
# - 104 Maximum Depth of Binary Tree.
#
# CSES:
#
# - Subordinates.
# - Company Queries I.
# - Tree Diameter.

# %% [markdown]
# ## 19. Cierre
#
# **Pregunta final para `notebook.md`:** explica en una frase la idea central de AVL como decisión de diseño.
